# %%
import pandas as pd

# %%
df = pd.read_csv('./train.csv')

# %%
df.head()
# Out:
#   origination_date  loan_amount  annual_interest_rate  repay_date  \
# 0       2016-12-01        42000                  0.26  2017-12-15
# 1       2016-11-09         5000                  0.28  2018-06-04
# 2       2017-07-02        36000                  0.28  2017-10-10
# 3       2016-04-16        22000                  0.20  2017-03-31
# 4       2015-01-27        11000                  0.20  2015-12-03
#
#    repay_amount  feature_0  feature_1  feature_2  feature_3  feature_4  \
# 0      53491.20   0.007000   0.010647  -0.003254  -0.007238  -0.011662
# 1       7561.75  -0.000041   0.011415   0.004384  -0.008996   0.002066
# 2          0.00   0.004082   0.004537  -0.002671  -0.007624  -0.001350
# 3      26189.85   0.002841   0.002211  -0.003884  -0.001883  -0.006990
# 4      13142.29   0.001302   0.007544   0.002545   0.002741  -0.013535
#
#       ...      feature_20  feature_21  feature_22  feature_23  feature_24  \
# ...

# %% [markdown]
# #### Calculate Time Elapsed in Days Between 'origination_date' and 'repay_date'
